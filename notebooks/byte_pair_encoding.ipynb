# %% [markdown]
# # Byte-Pair Encoding

# %%
text = "aaabdaaabac"
print(len(text))
# Out:
# 11

# %%
tokens = list(text.encode("utf-8"))
print(tokens)
# Out:
# [97, 97, 97, 98, 100, 97, 97, 97, 98, 97, 99]

# %%
def calc_bigram_freqs(tokens: list[int]) -> dict[tuple[int, int], int]:
    bigram_freqs = {}
    for bigram in zip(tokens[:-1], tokens[1:]):
        if bigram not in bigram_freqs:
            bigram_freqs[bigram] = 0
        bigram_freqs[bigram] += 1

    return bigram_freqs

bigram_freqs = calc_bigram_freqs(tokens)
print(bigram_freqs)
# Out:
# {(97, 97): 4, (97, 98): 2, (98, 100): 1, (100, 97): 1, (98, 97): 1, (97, 99): 1}

# %%
max_bigram = max(bigram_freqs, key=bigram_freqs.get)
print(max_bigram, bigram_freqs[max_bigram])
# Out:
# (97, 97) 4

# %%
def merge(tokens: list[int], bigram: tuple[int, int], new_token: int) -> list[int]:
    new_tokens = []

    i = 0
    while i < len(tokens):
        if (i == (len(tokens) - 1)) or ((tokens[i], tokens[i + 1]) != bigram):
            new_tokens.append(tokens[i])
        else:
            new_tokens.append(new_token)
            i += 1
        
        i += 1

    return new_tokens

new_tokens = merge(tokens, max_bigram, 255 + 1)
new_tokens
# Out:
# [256, 97, 98, 100, 256, 97, 98, 97, 99]

# %% [markdown]
# ## Regex

# %%
import re

split_pattern = r"""[ ']?[a-zA-Z]+|\d{1,4}|\s+(?!\S)|.+?"""
compiled_pattern = re.compile(split_pattern)

weird_str = "Hello, my NAme isn'tcool. \n\t  I like may number8834534s; and other things."
compiled_pattern.findall(weird_str)
# Out:
# ['Hello',
#  ',',
#  ' my',
#  ' NAme',
#  ' isn',
#  "'tcool",
#  '.',
#  ' \n\t ',
#  ' I',
#  ' like',
#  ' may',
#  ' number',
#  '8834',
#  '534',
#  's',
#  ';',
#  ' and',
#  ' other',
#  ' things',
#  '.']

# %%
with open("../data/shakespeare.txt") as f:
    shakespeare_text = f.read()

print(shakespeare_text[:100])
compiled_pattern.findall(shakespeare_text[:100])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You
# ['First',
#  ' Citizen',
#  ':',
#  'Before',
#  ' we',
#  ' proceed',
#  ' any',
#  ' further',
#  ',',
#  ' hear',
#  ' me',
#  ' speak',
#  '.',
#  '\n',
#  'All',
#  ':',
#  'Speak',
#  ',',
#  ' speak',
#  '.',
#  '\n',
#  'First',
#  ' Citizen',
#  ':',
#  'You']

# %% [markdown]
# ## Class

# %%
class BytePairEncoder:
    """Byte pair encoder."""

    def __init__(self, text: str, vocab_size: int) -> None:
        split_pattern = re.compile(r"""[ ']?[a-zA-Z]+|\d{1,4}|\s+(?!\S)|.+?""")
        text_chunks = split_pattern.findall(text)
        token_chunks = [list(chunk.encode("utf-8")) for chunk in text_chunks]

        self.merges: dict[tuple[int, int], int] = {}
        self.vocab: dict[int, bytes] = {i: bytes([i]) for i in range(256)}

        for i in range(vocab_size - 256):
            bigram_freqs = {}
            for chunk in token_chunks:
                bigram_freqs = self.calc_bigram_freqs(chunk, bigram_freqs)
            
            max_bigram = max(bigram_freqs, key=bigram_freqs.get)
            if bigram_freqs[max_bigram] == 1:
                break

            new_token = 256 + i
            token_chunks = [self.merge(chunk, max_bigram, new_token) for chunk in token_chunks]

            self.merges[max_bigram] = new_token
            self.vocab[new_token] = self.vocab[max_bigram[0]] + self.vocab[max_bigram[1]]

    def encode(self, text: str) -> list[int]:
        tokens = list(text.encode("utf-8"))
        while len(tokens) >= 2:
            bigram_freqs = self.calc_bigram_freqs(tokens)

            bigram = min(bigram_freqs, key=lambda bigram: self.merges.get(bigram, float("inf")))
            if bigram not in self.merges:
                break

            tokens = self.merge(tokens, bigram, self.merges[bigram])

        return tokens
    
    def decode(self, tokens: list[int]) -> str:
        text_bytes = b"".join(self.vocab[i] for i in tokens)
        return text_bytes.decode("utf-8", errors="replace")

    def calc_bigram_freqs(self, tokens: list[int], bigram_freqs: dict = None) -> dict[tuple[int, int], int]:
        if not bigram_freqs:
            bigram_freqs = {}
        for bigram in zip(tokens[:-1], tokens[1:]):
            if bigram not in bigram_freqs:
                bigram_freqs[bigram] = 0
            bigram_freqs[bigram] += 1

        return bigram_freqs
    
    def merge(self, tokens: list[int], bigram: tuple[int, int], new_token: int) -> list[int]:
        new_tokens = []

        i = 0
        while i < len(tokens):
            if (i == (len(tokens) - 1)) or ((tokens[i], tokens[i + 1]) != bigram):
                new_tokens.append(tokens[i])
            else:
                new_tokens.append(new_token)
                i += 1
        
            i += 1

        return new_tokens

# %%
bpe = BytePairEncoder(text="aaabdaaabac", vocab_size=256 + 16)
print(bpe.merges)

tokens = bpe.encode("aaabdaaabac")
print(tokens)
print(bpe.decode(tokens))
# Out:
# {(97, 97): 256, (256, 97): 257, (257, 98): 258}
# [258, 100, 258, 97, 99]
# aaabdaaabac

# %%
bpe = BytePairEncoder(text=shakespeare_text, vocab_size=1024)
print(bpe.merges)
print(bpe.vocab)

tokens = bpe.encode(shakespeare_text[:200])
print(tokens)
print(bpe.decode(tokens))
# Out:
# {(32, 116): 256, (104, 101): 257, (32, 97): 258, (111, 117): 259, (32, 115): 260, (32, 109): 261, (105, 110): 262, (32, 119): 263, (114, 101): 264, (104, 97): 265, (110, 100): 266, (256, 257): 267, (32, 98): 268, (105, 115): 269, (111, 114): 270, (32, 102): 271, (101, 114): 272, (108, 108): 273, (105, 116): 274, (111, 110): 275, (32, 100): 276, (32, 99): 277, (101, 115): 278, (101, 110): 279, (32, 110): 280, (32, 108): 281, (32, 121): 282, (256, 104): 283, (97, 114): 284, (32, 104): 285, (32, 111): 286, (256, 111): 287, (282, 259): 288, (32, 112): 289, (265, 116): 290, (32, 73): 291, (32, 257): 292, (115, 116): 293, (118, 101): 294, (111, 116): 295, (258, 266): 296, (111, 119): 297, (262, 103): 298, (97, 110): 299, (286, 102): 300, (111, 109): 301, (32, 103): 302, (97, 116): 303, (268, 101): 304, (115, 101): 305, (261, 121): 306, (32, 262): 307, (99, 101): 308, (32, 265): 309, (108, 101): 310, (97, 121): 311, (108, 100): 312, (105, 114): 313, (101, 116): 314, (101, 100): 315, (117, 116): 316, (261, 101): 317, (105, 109): 318, (274, 104): 319, (280, 295): 320, (99, 104): 321, (256, 290): 322, (32, 269): 323, (103, 104): 324, (65, 266): 325, (271, 270): 326, (39, 115): 327, (107, 101): 328, (32, 117): 329, (259, 114): 330, (263, 101): 331, (111, 111): 332, (105, 273): 333, (32, 101): 334, (257, 114): 335, (263, 319): 336, (279, 116): 337, (32, 274): 338, (288, 114): 339, (97, 100): 340, (114, 105): 341, (283, 259): 342, (260, 116): 343, (39, 100): 344, (32, 107): 345, (301, 101): 346, (285, 269): 347, (324, 116): 348, (69, 78): 349, (270, 100): 350, (105, 100): 351, (97, 115): 352, (84, 257): 353, (32, 264): 354, (309, 294): 355, (73, 78): 356, (108, 121): 357, (114, 97): 358, (281, 105): 359, (285, 318): 360, (117, 114): 361, (283, 269): 362, (97, 108): 363, (73, 79): 364, (260, 111): 365, (258, 115): 366, (276, 101): 367, (32, 275): 368, (111, 264): 369, (114, 111): 370, (65, 82): 371, (104, 105): 372, (259, 312): 373, (332, 100): 374, (99, 107): 375, (97, 262): 376, (118, 272): 377, (278, 116): 378, (283, 121): 379, (260, 265): 380, (278, 115): 381, (101, 97): 382, (276, 111): 383, (263, 333): 384, (97, 109): 385, (280, 111): 386, (268, 316): 387, (117, 115): 388, (97, 266): 389, (85, 83): 390, (105, 102): 391, (260, 101): 392, (103, 101): 393, (84, 104): 394, (258, 273): 395, (260, 117): 396, (97, 328): 397, (84, 111): 398, (292, 114): 399, (114, 117): 400, (105, 275): 401, (116, 104): 402, (258, 110): 403, (116, 272): 404, (284, 100): 405, (281, 111): 406, (265, 110): 407, (101, 273): 408, (101, 284): 409, (260, 112): 410, (267, 101): 411, (32, 330): 412, (271, 97): 413, (380, 273): 414, (268, 121): 415, (85, 67): 416, (105, 108): 417, (258, 264): 418, (356, 71): 419, (32, 67): 420, (280, 101): 421, (114, 301): 422, (104, 111): 423, (345, 110): 424, (65, 78): 425, (32, 82): 426, (84, 290): 427, (32, 118): 428, (69, 82): 429, (97, 293): 430, (79, 82): 431, (99, 116): 432, (259, 115): 433, (263, 290): 434, (105, 348): 435, (260, 104): 436, (117, 108): 437, (69, 84): 438, (299, 116): 439, (69, 83): 440, (329, 112): 441, (305, 108): 442, (113, 117): 443, (66, 316): 444, (284, 116): 445, (302, 374): 446, (114, 297): 447, (303, 104): 448, (262, 101): 449, (281, 350): 450, (39, 116): 451, (372, 321): 452, (110, 116): 453, (117, 293): 454, (39, 273): 455, (275, 101): 456, (289, 114): 457, (277, 301): 458, (258, 116): 459, (261, 299): 460, (32, 77): 461, (87, 290): 462, (263, 257): 463, (32, 69): 464, (75, 419): 465, (258, 109): 466, (101, 266): 467, (105, 99): 468, (277, 275): 469, (98, 310): 470, (114, 121): 471, (275, 103): 472, (105, 101): 473, (105, 294): 474, (271, 422): 475, (268, 108): 476, (118, 279): 477, (32, 71): 478, (70, 270): 479, (260, 257): 480, (101, 109): 481, (302, 111): 482, (97, 264): 483, (261, 369): 484, (267, 109): 485, (259, 116): 486, (73, 67): 487, (263, 352): 488, (97, 117): 489, (295, 335): 490, (295, 104): 491, (72, 101): 492, (260, 313): 493, (111, 108): 494, (280, 297): 495, (32, 76): 496, (32, 290): ...
# {0: b'\x00', 1: b'\x01', 2: b'\x02', 3: b'\x03', 4: b'\x04', 5: b'\x05', 6: b'\x06', 7: b'\x07', 8: b'\x08', 9: b'\t', 10: b'\n', 11: b'\x0b', 12: b'\x0c', 13: b'\r', 14: b'\x0e', 15: b'\x0f', 16: b'\x10', 17: b'\x11', 18: b'\x12', 19: b'\x13', 20: b'\x14', 21: b'\x15', 22: b'\x16', 23: b'\x17', 24: b'\x18', 25: b'\x19', 26: b'\x1a', 27: b'\x1b', 28: b'\x1c', 29: b'\x1d', 30: b'\x1e', 31: b'\x1f', 32: b' ', 33: b'!', 34: b'"', 35: b'#', 36: b'$', 37: b'%', 38: b'&', 39: b"'", 40: b'(', 41: b')', 42: b'*', 43: b'+', 44: b',', 45: b'-', 46: b'.', 47: b'/', 48: b'0', 49: b'1', 50: b'2', 51: b'3', 52: b'4', 53: b'5', 54: b'6', 55: b'7', 56: b'8', 57: b'9', 58: b':', 59: b';', 60: b'<', 61: b'=', 62: b'>', 63: b'?', 64: b'@', 65: b'A', 66: b'B', 67: b'C', 68: b'D', 69: b'E', 70: b'F', 71: b'G', 72: b'H', 73: b'I', 74: b'J', 75: b'K', 76: b'L', 77: b'M', 78: b'N', 79: b'O', 80: b'P', 81: b'Q', 82: b'R', 83: b'S', 84: b'T', 85: b'U', 86: b'V', 87: b'W', 88: b'X', 89: b'Y', 90: b'Z', 91: b'[', 92: b'\\', 93: b']', 94: b'^', 95: b'_', 96: b'`', 97: b'a', 98: b'b', 99: b'c', 100: b'd', 101: b'e', 102: b'f', 103: b'g', 104: b'h', 105: b'i', 106: b'j', 107: b'k', 108: b'l', 109: b'm', 110: b'n', 111: b'o', 112: b'p', 113: b'q', 114: b'r', 115: b's', 116: b't', 117: b'u', 118: b'v', 119: b'w', 120: b'x', 121: b'y', 122: b'z', 123: b'{', 124: b'|', 125: b'}', 126: b'~', 127: b'\x7f', 128: b'\x80', 129: b'\x81', 130: b'\x82', 131: b'\x83', 132: b'\x84', 133: b'\x85', 134: b'\x86', 135: b'\x87', 136: b'\x88', 137: b'\x89', 138: b'\x8a', 139: b'\x8b', 140: b'\x8c', 141: b'\x8d', 142: b'\x8e', 143: b'\x8f', 144: b'\x90', 145: b'\x91', 146: b'\x92', 147: b'\x93', 148: b'\x94', 149: b'\x95', 150: b'\x96', 151: b'\x97', 152: b'\x98', 153: b'\x99', 154: b'\x9a', 155: b'\x9b', 156: b'\x9c', 157: b'\x9d', 158: b'\x9e', 159: b'\x9f', 160: b'\xa0', 161: b'\xa1', 162: b'\xa2', 163: b'\xa3', 164: b'\xa4', 165: b'\xa5', 166: b'\xa6', 167: b'\xa7', 168: b'\xa8', 169: b'\xa9', 170: b'\xaa', 171: b'\xab', 172: b'\xac', 173: b'\xad', 174: b'\xae', 175: b'\xaf', 176: b'\xb0', 177: b'\xb1', 178: b'\xb2', 179: b'\xb3', 180: b'\xb4', 181: b'\xb5', 182: b'\xb6', 183: b'\xb7', 184: b'\xb8', 185: b'\xb9', 186: b'\xba', 187: b'\xbb', 188: b'\xbc', 189: b'\xbd', 190: b'\xbe', 191: b'\xbf', 192: b'\xc0', 193: b'\xc1', 194: b'\xc2', 195: b'\xc3', 196: b'\xc4', 197: b'\xc5', 198: b'\xc6', 199: b'\xc7', 200: b'\xc8', 201: b'\xc9', 202: b'\xca', 203: b'\xcb', 204: b'\xcc', 205: b'\xcd', 206: b'\xce', 207: b'\xcf', 208: b'\xd0', 209: b'\xd1', 210: b'\xd2', 211: b'\xd3', 212: b'\xd4', 213: b'\xd5', 214: b'\xd6', 215: b'\xd7', 216: b'\xd8', 217: b'\xd9', 218: b'\xda', 219: b'\xdb', 220: b'\xdc', 221: b'\xdd', 222: b'\xde', 223: b'\xdf', 224: b'\xe0', 225: b'\xe1', 226: b'\xe2', 227: b'\xe3', 228: b'\xe4', 229: b'\xe5', 230: b'\xe6', 231: b'\xe7', 232: b'\xe8', 233: b'\xe9', 234: b'\xea', 235: b'\xeb', 236: b'\xec', 237: b'\xed', 238: b'\xee', 239: b'\xef', 240: b'\xf0', 241: b'\xf1', 242: b'\xf2', 243: b'\xf3', 244: b'\xf4', 245: b'\xf5', 246: b'\xf6', 247: b'\xf7', 248: b'\xf8', 249: b'\xf9', 250: b'\xfa', 251: b'\xfb', 252: b'\xfc', 253: b'\xfd', 254: b'\xfe', 255: b'\xff', 256: b' t', 257: b'he', 258: b' a', 259: b'ou', 260: b' s', 261: b' m', 262: b'in', 263: b' w', 264: b're', 265: b'ha', 266: b'nd', 267: b' the', 268: b' b', 269: b'is', 270: b'or', 271: b' f', 272: b'er', 273: b'll', 274: b'it', 275: b'on', 276: b' d', 277: b' c', 278: b'es', 279: b'en', 280: b' n', 281: b' l', 282: b' y', 283: b' th', 284: b'ar', 285: b' h', 286: b' o', 287: b' to', 288: b' you', 289: b' p', 290: b'hat', 291: b' I', 292: b' he', 293: b'st', 294: b've', 295: b'ot', 296: b' and', 297: b'ow', 298: b'ing', 299: b'an', 300: b' of', 301: b'om', 302: b' g', 303: b'at', 304: b' be', 305: b'se', 306: b' my', 307: b' in', 308: b'ce', 309: b' ha', 310: b'le', 311: b'ay', 312: b'ld', 313: b'ir', 314: b'et', 315: b'ed', 316: b'ut', 317: b' me', 318: b'im', 319: b'ith', 320: b' not', 321: b'ch', 322 ...
# [669, 420, 939, 58, 10, 773, 547, 331, 583, 308, 315, 801, 271, 361, 709, 44, 671, 317, 613, 46, 10, 10, 65, 273, 58, 10, 83, 112, 579, 44, 613, 46, 10, 10, 669, 420, 939, 58, 10, 564, 418, 395, 354, 115, 494, 766, 614, 511, 287, 964, 526, 287, 271, 385, 555, 63, 10, 10, 65, 273, 58, 10, 82, 278, 494, 766, 46, 354, 115, 494, 766, 46, 10, 10, 669, 420, 939, 58, 10, 669, 44, 288]
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you

# %%
for i in range(256, len(bpe.vocab)):
    print(bpe.vocab[i])
# Out:
# b' t'
# b'he'
# b' a'
# b'ou'
# b' s'
# b' m'
# b'in'
# b' w'
# b're'
# b'ha'
# b'nd'
# b' the'
# b' b'
# b'is'
# b'or'
# b' f'
# b'er'
# b'll'
# b'it'
# b'on'
# b' d'
# b' c'
# b'es'
# b'en'
# b' n'
# b' l'
# b' y'
# b' th'
# b'ar'
# b' h'
# b' o'
# b' to'
# b' you'
# b' p'
# b'hat'
# b' I'
# b' he'
# b'st'
# b've'
# b'ot'
# b' and'
# b'ow'
# b'ing'
# b'an'
# b' of'
# b'om'
# b' g'
# b'at'
# b' be'
# b'se'
# b' my'
# b' in'
# b'ce'
# b' ha'
# b'le'
# b'ay'
# b'ld'
# b'ir'
# b'et'
# b'ed'
# b'ut'
# b' me'
# b'im'
# b'ith'
# b' not'
# b'ch'
# b' that'
# b' is'
# b'gh'
# b'And'
# b' for'
# b"'s"
# b'ke'
# b' u'
# b'our'
# b' we'
# b'oo'
# b'ill'
# b' e'
# b'her'
# b' with'
# b'ent'
# b' it'
# b' your'
# b'ad'
# b'ri'
# b' thou'
# b' st'
# b"'d"
# b' k'
# b'ome'
# b' his'
# b'ght'
# b'EN'
# b'ord'
# b'id'
# b'as'
# b'The'
# b' re'
# b' have'
# b'IN'
# b'ly'
# b'ra'
# b' li'
# b' him'
# b'ur'
# b' this'
# b'al'
# b'IO'
# b' so'
# b' as'
# b' de'
# b' on'
# b'ore'
# b'ro'
# b'AR'
# b'hi'
# b'ould'
# b'ood'
# b'ck'
# b'ain'
# b'ver'
# b'est'
# b' thy'
# b' sha'
# b'ess'
# b'ea'
# b' do'
# b' will'
# b'am'
# b' no'
# b' but'
# b'us'
# b'and'
# b'US'
# b'if'
# b' se'
# b'ge'
# b'Th'
# b' all'
# b' su'
# b'ake'
# b'To'
# b' her'
# b'ru'
# b'ion'
# b'th'
# b' an'
# b'ter'
# b'ard'
# b' lo'
# b'han'
# b'ell'
# b'ear'
# b' sp'
# b' thee'
# b' our'
# b' fa'
# b' shall'
# b' by'
# b'UC'
# b'il'
# b' are'
# b'ING'
# b' C'
# b' ne'
# b'rom'
# b'ho'
# b' kn'
# b'AN'
# b' R'
# b'That'
# b' v'
# b'ER'
# b'ast'
# b'OR'
# b'ct'
# b'ous'
# b' what'
# b'ight'
# b' sh'
# b'ul'
# b'ET'
# b'ant'
# b'ES'
# b' up'
# b'sel'
# b'qu'
# b'But'
# b'art'
# b' good'
# b'row'
# b'ath'
# b'ine'
# b' lord'
# b"'t"
# b'hich'
# b'nt'
# b'ust'
# b"'ll"
# b'one'
# b' pr'
# b' com'
# b' at'
# b' man'
# b' M'
# b'What'
# b' whe'
# b' E'
# b'KING'
# b' am'
# b'end'
# b'ic'
# b' con'
# b'ble'
# b'ry'
# b'ong'
# b'ie'
# b'ive'
# b' from'
# b' bl'
# b'ven'
# b' G'
# b'For'
# b' she'
# b'em'
# b' go'
# b'are'
# b' more'
# b' them'
# b'out'
# b'IC'
# b' was'
# b'au'
# b'other'
# b'oth'
# b'He'
# b' sir'
# b'ol'
# b' now'
# b' L'
# b' hat'
# b' if'
# b'ost'
# b'LO'
# b'ind'
# b' there'
# b' know'
# b' would'
# b' can'
# b'ers'
# b'IUS'
# b'ep'
# b'self'
# b'ARD'
# b'ather'
# b'fe'
# b'ond'
# b'res'
# b'ate'
# b' say'
# b' here'
# b' love'
# b' their'
# b' sw'
# b' br'
# b'pp'
# b' or'
# b'all'
# b' S'
# b' than'
# b' king'
# b' then'
# b' us'
# b' O'
# b' they'
# b' B'
# b' ar'
# b'od'
# b'My'
# b' let'
# b' un'
# b'ig'
# b' wor'
# b'ure'
# b'ink'
# b' H'
# b'ort'
# b'hy'
# b'ame'
# b' V'
# b'fore'
# b'As'
# b' may'
# b'el'
# b' come'
# b' qu'
# b'ook'
# b'Whe'
# b'ish'
# b'LI'
# b' well'
# b'KE'
# b'ves'
# b' j'
# b' one'
# b' hath'
# b'irst'
# b'You'
# b' make'
# b'reat'
# b'gain'
# b'ak'
# b' must'
# b'ound'
# b'ng'
# b' gra'
# b' were'
# b' ho'
# b'ci'
# b' see'
# b' like'
# b'ue'
# b'eak'
# b' should'
# b'TIO'
# b'ity'
# b' pro'
# b' mad'
# b' sa'
# b' P'
# b'um'
# b' pl'
# b' father'
# b'RO'
# b'AU'
# b' had'
# b' did'
# b'pe'
# b'ime'
# b' upon'
# b'ice'
# b' too'
# b'ON'
# b'ence'
# b' W'
# b'ward'
# b'ist'
# b' death'
# b'own'
# b' en'
# b'ose'
# b'man'
# b'un'
# b'ful'
# b'IS'
# b'nce'
# b' speak'
# b' r'
# b' po'
# b'entle'
# b'de'
# b' out'
# b'io'
# b' which'
# b'pt'
# b'ICH'
# b' fri'
# b'OL'
# b' again'
# b'DU'
# b'DUKE'
# b' how'
# b'EL'
# b' A'
# b' heart'
# b' tru'
# b'ick'
# b' hand'
# b' yet'
# b'Thou'
# b'CA'
# b'very'
# b'ICHARD'
# b'ENTIO'
# b'With'
# b'ign'
# b'ance'
# b' some'
# b' who'
# b'Which'
# b'If'
# b' when'
# b'ies'
# b' mar'
# b'ire'
# b' hon'
# b' mine'
# b'orn'
# b'har'
# b' off'
# b'ince'
# b'INC'
# b'ack'
# b'In'
# b' Y'
# b' dis'
# b' son'
# b' al'
# b'We'
# b'wn'
# b' hea'
# b'uch'
# b'First'
# b'oy'
# b' hear'
# b' time'
# b'ec'
# b' such'
# b'AB'
# b'ness'
# b' brother'
# b'LA'
# b'Of'
# b' blood'
# b'ither'
# b' ab'
# b' these'
# b'Why'
# b'UE'
# b'No'
# b' give'
# b' fo'
# b' day'
# b' ear'
# b' RICHARD'
# b' II'
# b'ise'
# b' ex'
# b' ro'
# b'This'
# b' life'
# b'EST'
# b' tell'
# b'eet'
# b' think'
# b'So'
# b' look'
# b'UCH'
# b' word'
# b' where'
# b' ey'
# b'oul'
# b'ther'
# b'age'
# b'ag'
# b'een'
# b' friend'
# b' take'
# b'GLO'
# b'GLOUC'
# b'GLOUCEST'
# b'GLOUCESTER'
# b'ef'
# b'erv'
# b'ady'
# b'rown'
# b'ings'
# b' des'
# b'not'
# b'ave'
# b'urse'
# b' gentle'
# b' ri'
# b'How'
# b'RY'
# b'ase'
# b'way'
# b"'st"
# b'QUE'
# b'QUEEN'
# b'INCENTIO'
# b' lea'
# b' OF'
# b' art'
# b' most'
# b'Where'
# b' honour'
# b' much'
# b'LAN'
# b' sl'
# b' war'
# b' fl'
# b'urn'
# b' made'
# b'ment'
# b"'tis"
# b'Now'
# b' hast'
# b' fear'
# b' tw'
# b' T'
# b' bet'
# b'aught'
# b'ENRY'
# b'Is'
# b'ff'
# b'ber'
# b' God'
# b'LE'
# b'ved'
# b'ough'
# b' bre'
# b'cc'
# b' never'
# b'ower'
# b' VINCENTIO'
# b'Be'
# b'ap'
# b'igh'
# b' great'
# b' fair'
# b' K'
# b' cou'
# b' men'
# b'itt'
# b'Who'
# b'ee'
# b' Rome'
# b' new'
# b'aster'
# b'orrow'
# b'uke'
# b'iz'
# b'old'
# b'ORK'
# b' part'
# b'ation'
# b'INIUS'
# b'ide'
# b'ree'
# b'ss'
# b"'er"
# b'Or'
# b' call'
# b' any'
# b'ple'
# b' heaven'
# b' ad'
# b' comm'
# b"'T"
# b' cannot'
# b'Your'
# b'It'
# b' stand'
# b' true'
# b' been'
# b'ears'
# b' name'
# b'DW'
# b'DWARD'
# b' cl'
# b' pre'
# b' sweet'
# b' pray'
# b' doth'
# b'hing'
# b' noble'
# b'UM'
# b'PET'
# b' own'
# b'MEN'
# b' ple'
# b'ass'
# b'TH'
# b'LUC'
# b'ouse'
# b' per'
# b' D'
# b'Come'
# b'There'
# b'Ay'
# b'ull'
# b' done'
# b'ife'
# b' wr'
# b' tr'
# b'aw'
# b' way'
# b' other'
# b' head'
# b' mean'
# b'li'
# b'When'
# b'red'
# b' nor'
# b'dward'
# b' sc'
# b' pres'
# b' soul'
# b'ROM'
# b'ROME'
# b'ROMEO'
# b'MENEN'
# b'MENENIUS'
# b' bear'
# b' world'
# b'ace'
# b'aint'
# b' night'
# b'ving'
# b' Cl'
# b'ause'
# b'ger'
# b' before'
# b' both'
# b' queen'
# b'per'
# b'Then'
# b'aughter'
# b' chi'
# b' mo'
# b'Here'
# b'PETR'
# b'PETRUCH'
# b'PETRUCHIO'
# b' very'
# b'able'
# b'OM'
# b' dead'
# b'TES'
# b' ra'
# b'ite'
# b'By'
# b'to'
# b' ke'
# b'les'
# b'the'
# b'ab'
# b' down'
# b' F'
# b' cont'
# b' app'
# b'Than'
# b' myself'
# b' arm'
# b' rem'
# b' wh'
# b' Lord'
# b'HA'
# b'GR'
# b' thus'
# b'ilt'
# b'ORIO'
# b'ORIOLAN'
# b'ORIOLANUS'
# b'Sec'
# b'Second'
# b' leave'
# b'CORIOLANUS'
# b' being'
# b'ction'
# b'lo'
# b' Edward'
# b' unt'
# b'sw'
# b' grace'
# b'Nor'
# b'ress'
# b' eyes'
# b'less'
# b' beg'
# b' mother'
# b'land'
# b'led'
# b'BA'
# b'ran'
# b' old'
# b' ma'
# b' im'
# b' EDWARD'
# b'INA'
# b'itiz'
# b'itizen'
# b' Mar'
# b' ever'
# b'ps'
# b' long'
# b' live'
# b' child'
# b'me'
# b'Let'
# b' wife'
# b' away'
# b' rep'
# b'She'
# b' III'
# b' poor'
# b' friends'
# b' wom'
# b' might'
# b'come'
# b' af'
# b'for'
# b'wick'
# b' stay'
# b'nder'
# b'eace'
# b' die'
# b'oud'
# b'ks'
# b'atch'
# b' comes'
# b' ru'
# b' J'
# b' cons'
# b'arwick'
# b' many'
# b'ows'
# b' crown'
# b' pe'
# b' le'
# b'hall'
# b"'Tis"
# b'ison'
# b' YORK'
# b' rest'
# b' thought'
# b'iss'
# b'uck'
# b' har'
# b' house'
# b'ISAB'
# b'ISABEL'
# b'ISABELLA'
# b' cour'
# b'ian'
# b' ent'
# b' lie'
# b'RAN'
# b' set'
# b'che'
# b'atter'
# b'ors'
# b'erc'
# b'well'
# b' Warwick'
# b'JU'
# b'JULI'
# b'JULIET'
# b'LEON'
# b'LEONTES'
# b'Nay'
# b'ittle'
# b'int'
# b' gone'
# b' daughter'
# b' better'
# b'rant'
# b'ought'
# b' prince'
# b'MI'
# b' tong'
# b'His'
# b' nothing'
# b'DY'
# b'VOL'
# b'ENC'
